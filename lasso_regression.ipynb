# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Lasso, Ridge, RidgeCV, LassoCV
from sklearn.model_selection import train_test_split, RepeatedKFold

import warnings

# Filter out import warnings
warnings.filterwarnings("ignore", category=ImportWarning)

# %%
df = pd.read_csv('data/data.csv')

# %%
data = df.reindex(columns=['DEP_DELAY', 'CRS_ELAPSED_TIME', 'DISTANCE', 'CRS_DEP_M', 'DEP_TIME_M', 'CRS_ARR_M', 'Temperature', 'Dew_Point', 'Wind Gust', 'Pressure', 'sch_dep', 'sch_arr', 'TAXI_OUT'])

# %%
data_to_use = data.iloc[:,0:12]
data_to_target = data.iloc[:,12]

# %%
#define our model
model_lasso = Lasso(alpha=0.01)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_to_use, data_to_target, test_size=20, random_state=32)

# %%
#fit model
model_lasso.fit(X_train,y_train)
# Out:
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.090e+02, tolerance: 1.353e+02
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.01)

# %%
data_to_use
# Out:
#        DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  \
# 0             -1               124       636        324         323
# 1             -7               371      2475        340         333
# 2             40               181      1069        301         341
# 3             -2               168       944        345         343
# 4             -4               139       760        360         356
# ...          ...               ...       ...        ...         ...
# 28815          2                57       150       1370        1372
# 28816          2                75       187       1390        1392
# 28817        283               392      2422       1125        1408
# 28818          5               224      1598       1417        1422
# 28819         -1               225      1576       1439        1438
#
#        CRS_ARR_M  Temperature Dew_Point  Wind Gust  Pressure  sch_dep  sch_arr
# 0            448           48        34         38     29.86        9       17
# 1            531           48        34         38     29.86        9       17
# 2            482           48        34         38     29.86        9       17
# 3            513           48        34         38     29.86        9       17
# 4            499           46        32         35     29.91        9       17
# ...          ...          ...       ...        ...       ...      ...      ...
# 28815       1427           39        38          0     30.18       20       32
# 28816         25           39        38          0     30.18       19       23
# 28817       1337           39        38          0     30.18       19       23
# 28818        261           39        38          0     30.18       19       23
# 28819        284           39        38          0     30.18       19       23
#
# [28820 rows x 12 columns]

# %%
pred_lasso = model_lasso.predict(X_test)
pred_lasso
# Out:
# array([22.45689303, 22.80265167, 23.16915718, 25.32762786, 18.4467336 ,
#        18.0856135 , 23.63380803, 18.96978431, 18.20560717, 22.31205698,
#        23.50939402, 22.99282286, 20.78459686, 20.6893317 , 19.99241195,
#        21.23749644, 22.50505099, 22.96698522, 20.55558322, 22.76542415])

# %%
## mnake prediction in a dataframe
lasso_df = pd.DataFrame({'Actual_score': y_test, 'Predicted_score': pred_lasso})
lasso_df
# Out:
#        Actual_score  Predicted_score
# 9362             23        22.456893
# 23840            14        22.802652
# 24617            22        23.169157
# 24899            19        25.327628
# 2007             20        18.446734
# 8034             16        18.085613
# 7222             21        23.633808
# 17910            16        18.969784
# 911              16        18.205607
# 10602            19        22.312057
# 13680            23        23.509394
# 13371            17        22.992823
# 28016            20        20.784597
# 4058             14        20.689332
# 7747             19        19.992412
# 13844            29        21.237496
# 25418            16        22.505051
# 10230            20        22.966985
# 4501             16        20.555583
# 24447            17        22.765424

# %%
#tuning alpha
#n_repeats number of times of training it will shuffle and repeat ...computeration and space needs to be consider
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

model = LassoCV(alphas=(0.5, 1, 0.01), cv=cv)

## fit the model
model.fit(X_test,y_test)
# Out:
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.134421127585, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4403424499788429, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.73115395274879, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.873220400717372, tolerance: 0.02265
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3812430427558127, tolerance: 0.02265
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.99417402326028, tolerance: 0.02265
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.095097292562727, tolerance: 0.023999999999999997
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.159530656903925, tolerance: 0.023999999999999997
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.64722998457823, tolerance: 0.023999999999999997
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7113580184804391, tolerance: 0.02476111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7336894847774857, tolerance: 0.02476111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.51942593348974, tolerance: 0.02476111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.1609869615427115, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7126218747201705, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.115224791615042, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4166884238650823, tolerance: 0.02097777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3500538347438322, tolerance: 0.02097777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.86904746670312, tolerance: 0.02097777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26677444913863724, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.90938691192615, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5117842975068712, tolerance: 0.014161111111111109
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5148422360288905, tolerance: 0.014161111111111109
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.626133136279547, tolerance: 0.014161111111111109
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6859906719122222, tolerance: 0.024094444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1193657550304579, tolerance: 0.024094444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.27372172784732, tolerance: 0.024094444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.188448570704381, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.534251583771862, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.37744817603851, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9167555163025654, tolerance: 0.013644444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11846096842484144, tolerance: 0.013644444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.575307441223122, tolerance: 0.013644444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.134421127585, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4403424499788429, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.73115395274879, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0071705542035403, tolerance: 0.024577777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22487982830610065, tolerance: 0.024577777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.756951913656074, tolerance: 0.024577777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.53776698258406, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6758164709793135, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.72261304975718, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33100993980802684, tolerance: 0.023044444444444444
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.86159575449088, tolerance: 0.023044444444444444
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.828436904389164, tolerance: 0.02257777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6199867068576594, tolerance: 0.02257777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.556747749127108, tolerance: 0.02257777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.374380616734243, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.215475316311142, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.584127730130305, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5809141604517407, tolerance: 0.023827777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9899135623160475, tolerance: 0.023827777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.708498845970745, tolerance: 0.023827777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.21635499613258, tolerance: 0.023227777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.137874489187837, tolerance: 0.023227777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.30854158967044, tolerance: 0.023227777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2698241642437864, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20993336215680358, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.36609792526846, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5809141604517407, tolerance: 0.023827777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9899135623160475, tolerance: 0.023827777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.708498845970745, tolerance: 0.023827777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22024130579470125, tolerance: 0.02409444444444445
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.85875267692966, tolerance: 0.02409444444444445
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.562402598761736, tolerance: 0.02429444444444445
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.405228927025433, tolerance: 0.02429444444444445
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.40867182608943, tolerance: 0.02429444444444445
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.53776698258406, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6758164709793135, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.72261304975718, tolerance: 0.02377777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.6539647769376415, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.771955180541539, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.59682430820384, tolerance: 0.024200000000000003
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5117842975068712, tolerance: 0.014161111111111109
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5148422360288905, tolerance: 0.014161111111111109
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.626133136279547, tolerance: 0.014161111111111109
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.644428693341055, tolerance: 0.023227777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1039919128889153, tolerance: 0.023227777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.01079810830336, tolerance: 0.023227777777777778
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9349042079024628, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5678099861475374, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.72587243637461, tolerance: 0.02156111111111111
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7611313005332221, tolerance: 0.024094444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3515423788235381, tolerance: 0.024094444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.71928830985238, tolerance: 0.024094444444444443
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.150169975388231, tolerance: 0.020977777777777776
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.372210173490899, tolerance: 0.020977777777777776
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.669699351511076, tolerance: 0.020977777777777776
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/james/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.068e+00, tolerance: 2.506e-02
#   model = cd_fast.enet_coordinate_descent(
# LassoCV(alphas=(0.5, 1, 0.01),
#         cv=RepeatedKFold(n_repeats=3, n_splits=10, random_state=1))

# %%
##summarise the chosen configuration
##this tells you the perfect alpha to use
model.alpha_
# Out:
# 1.0
