# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Lasso, Ridge, RidgeCV, LassoCV
from sklearn.model_selection import train_test_split, RepeatedKFold

import warnings

# Filter out import warnings
warnings.filterwarnings("ignore", category=ImportWarning)
# Out:
# /var/folders/z3/xgyml3416lx7m5d_s0_7fs9r0000gn/T/ipykernel_30073/2662566308.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('data/updated_data.csv')

# %%
data = df.reindex(columns=['DEP_DELAY', 'CRS_ELAPSED_TIME', 'DISTANCE', 'CRS_DEP_M', 'DEP_TIME_M', 'CRS_ARR_M', 'Temperature', 'Dew_Point', 'Wind Gust', 'Pressure', 'sch_dep', 'sch_arr', 'TAXI_OUT'])

# %%
data_to_use = data.iloc[:,0:12]
data_to_target = data.iloc[:,12]

# %%
#define our model
model_lasso = Lasso(alpha=0.01)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_to_use, data_to_target, test_size=20, random_state=32)

# %%
#fit model
model_lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.01)

# %%
data_to_use
# Out:
#        DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  \
# 0           -1.0               124     636.0        324         323
# 1           -7.0               371    2475.0        340         333
# 2           -3.0               181    1069.0        301         341
# 3           -2.0               168     944.0        345         343
# 4           -4.0               139     760.0        360         356
# ...          ...               ...       ...        ...         ...
# 28815        2.0                57     150.0       1370        1372
# 28816        2.0                75     187.0       1390        1392
# 28817       -3.0               392    2422.0       1125        1408
# 28818        5.0               224    1598.0       1417        1422
# 28819       -1.0               225    1576.0       1439        1438
#
#        CRS_ARR_M  Temperature  Dew_Point  Wind Gust  Pressure  sch_dep  \
# 0            448           48       34.0        0.0     29.86        9
# 1            531           48       34.0        0.0     29.86        9
# 2            482           48       34.0        0.0     29.86        9
# 3            513           48       34.0        0.0     29.86        9
# 4            499           46       32.0        0.0     29.91        9
# ...          ...          ...        ...        ...       ...      ...
# 28815       1427           39       38.0        0.0     30.18       20
# 28816         25           39       38.0        0.0     30.18       19
# 28817       1337           39       38.0        0.0     30.18       19
# 28818        261           39       38.0        0.0     30.18       19
# 28819        284           39       38.0        0.0     30.18       19
#
#        sch_arr
# 0           17
# 1           17
# 2           17
# 3           17
# 4           17
# ...        ...
# 28815       32
# 28816       23
# 28817       23
# 28818       23
# 28819       23
#
# [28820 rows x 12 columns]

# %%
pred_lasso = model_lasso.predict(X_test)
pred_lasso
# Out:
# array([22.49444284, 20.76928965, 21.72784874, 23.69715515, 19.00963763,
#        18.66833075, 22.26817712, 18.93519512, 18.02975694, 23.02619773,
#        20.99623067, 22.9323603 , 20.39772087, 21.16383869, 20.89475041,
#        20.05542112, 22.02023795, 21.77868241, 20.64796348, 23.07795792])

# %%
## mnake prediction in a dataframe
lasso_df = pd.DataFrame({'Actual_score': y_test, 'Predicted_score': pred_lasso})
lasso_df
# Out:
#        Actual_score  Predicted_score
# 9362             23        22.494443
# 23840            14        20.769290
# 24617            22        21.727849
# 24899            19        23.697155
# 2007             20        19.009638
# 8034             16        18.668331
# 7222             21        22.268177
# 17910            16        18.935195
# 911              16        18.029757
# 10602            19        23.026198
# 13680            23        20.996231
# 13371            17        22.932360
# 28016            20        20.397721
# 4058             14        21.163839
# 7747             19        20.894750
# 13844            29        20.055421
# 25418            16        22.020238
# 10230            20        21.778682
# 4501             16        20.647963
# 24447            17        23.077958

# %%
#tuning alpha
#n_repeats number of times of training it will shuffle and repeat ...computeration and space needs to be consider
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

model = LassoCV(alphas=(0.5, 1, 0.01), cv=cv)

## fit the model
model.fit(X_train,y_train)
# Out:
# LassoCV(alphas=(0.5, 1, 0.01),
#         cv=RepeatedKFold(n_repeats=3, n_splits=10, random_state=1))

# %%
##summarise the chosen configuration
##this tells you the perfect alpha to use
model.alpha_
# Out:
# 1.0
